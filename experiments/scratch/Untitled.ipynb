# %%
import os
import numpy as np

# 1. Let's find exactly where we are
print(f"Current Notebook Location: {os.getcwd()}")

# 2. Try the 'Relative Path' (Up one level)
base_path = "../data/processed/bharatanatyam/"
file_stem = "auto_bharatanatyam_66NYMTpR9YU_020"

# Check if the Merged file is there first
merged_file = os.path.join(base_path, f"{file_stem}.npz")
if os.path.exists(merged_file):
    print(f"✅ Found Merged File: {merged_file}")
    data = np.load(merged_file, allow_pickle=True)
    print(f"Keys inside Merged: {list(data.keys())}")
else:
    print(f"❌ Merged File NOT found at: {merged_file}")
# Out:
# Current Notebook Location: D:\New folder (2)\files (3)\natyaveda-v2-full\natyaveda-v2
# ❌ Merged File NOT found at: ../data/processed/bharatanatyam/auto_bharatanatyam_66NYMTpR9YU_020.npz
